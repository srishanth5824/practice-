# %% [markdown]
# <a href="https://colab.research.google.com/github/srishanth6824/practice-/blob/main/day7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.drop('species',axis=1,inplace=True)

# %%
oh_species=pd.get_dummies(['species'])
oh_species
# Out:
#    species
# 0     True

# %%
data=pd.concat([df,oh_species],axis=1)
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width species
# 0             5.1          3.5           1.4          0.2    True
# 1             4.9          3.0           1.4          0.2     NaN
# 2             4.7          3.2           1.3          0.2     NaN
# 3             4.6          3.1           1.5          0.2     NaN
# 4             5.0          3.6           1.4          0.2     NaN
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3     NaN
# 146           6.3          2.5           5.0          1.9     NaN
# 147           6.5          3.0           5.2          2.0     NaN
# 148           6.2          3.4           5.4          2.3     NaN
# 149           5.9          3.0           5.1          1.8     NaN
#
# [150 rows x 5 columns]

# %%
oh_species=pd.get_dummies(df['species'])
data=pd.concat([
